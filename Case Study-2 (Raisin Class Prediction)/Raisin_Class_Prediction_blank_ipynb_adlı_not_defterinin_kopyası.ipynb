# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # Raisin Class Prediction

# %% [markdown]
# Data Set Information:
#
# Images of Kecimen and Besni raisin varieties grown in Turkey were obtained with CVS. A total of 900 raisin grains were used, including 450 pieces from both varieties. These images were subjected to various stages of pre-processing and 7 morphological features were extracted. These features have been classified using three different artificial intelligence techniques.
#
#
# Attribute Information:
#
# 1. Area: Gives the number of pixels within the boundaries of the raisin.
# 2. Perimeter: It measures the environment by calculating the distance between the boundaries of the raisin and the pixels around it.
# 3. MajorAxisLength: Gives the length of the main axis, which is the longest line that can be drawn on the raisin.
# 4. MinorAxisLength: Gives the length of the small axis, which is the shortest line that can be drawn on the raisin.
# 5. Eccentricity: It gives a measure of the eccentricity of the ellipse, which has the same moments as raisins.
# 6. ConvexArea: Gives the number of pixels of the smallest convex shell of the region formed by the raisin.
# 7. Extent: Gives the ratio of the region formed by the raisin to the total pixels in the bounding box.
# 8. Class: Kecimen and Besni raisin.
#
# https://archive.ics.uci.edu/ml/datasets/Raisin+Dataset

# %% [markdown]
# # Import libraries

# %%
# libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import cufflinks as cf
#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
#To display the plots
# %matplotlib inline

# sklearn library for machine learning algorithms, data preprocessing, and evaluation
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, log_loss, recall_score, accuracy_score, precision_score, f1_score

# yellowbrick library for visualizing the model performance
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.cluster import KElbowVisualizer 

from sklearn.pipeline import Pipeline
# to get rid of the warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23800\1997755621.py in <module>
#       6 import plotly
#       7 import plotly.express as px
# ----> 8 import cufflinks as cf
#       9 #Enabling the offline mode for interactive plotting locally
#      10 from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
conda install -c conda-forge cufflinks-py
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... done
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3
#
#   added / updated specs:
#     - cufflinks-py
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2021.11  |           py39_0           7 KB
#     anaconda-custom            |           py39_1           4 KB
#     black-22.6.0               |   py39hcbf5309_2         295 KB  conda-forge
#     ca-certificates-2022.6.15  |       h5b45459_0         188 KB  conda-forge
#     certifi-2022.6.15          |   py39hcbf5309_0         155 KB  conda-forge
#     chart-studio-1.1.0         |     pyh9f0ad1d_0          51 KB  conda-forge
#     click-8.1.3                |   py39hcbf5309_0         146 KB  conda-forge
#     colorlover-0.3.0           |             py_0          12 KB  conda-forge
#     conda-4.12.0               |   py39hcbf5309_0         1.0 MB  conda-forge
#     cufflinks-py-0.17.3        |             py_0           4 KB  conda-forge
#     ipykernel-6.15.1           |     pyh025b116_0          96 KB  conda-forge
#     openssl-1.1.1q             |       h8ffe710_0         5.8 MB  conda-forge
#     pathspec-0.9.0             |     pyhd8ed1ab_0          31 KB  conda-forge
#     platformdirs-2.5.2         |     pyhd8ed1ab_1          16 KB  conda-forge
#     plotly-5.10.0              |     pyhd8ed1ab_0         7.0 MB  conda-forge
#     python-cufflinks-0.17.3    |             py_0          59 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     scikit-learn-1.1.1         |   py39hd77b12b_0         5.5 MB
#     tenacity-8.0.1             |     pyhd8ed1ab_0          21 KB  conda-forge
#     tomli-2.0.1                |     pyhd8ed1ab_0          16 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        20.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2021.11-py39_0
#   black              conda-forge/win-64::black-22.6.0-py39hcbf5309_2
#   chart-studio       conda-forge/noarch::chart-studio-1.1.0-pyh9f0ad1d_0
#   click              conda-forge/win-64::click-8.1.3-py39hcbf5309_0
#   colorlover         conda-forge/noarch::colorlover-0.3.0-py_0
#   cufflinks-py       conda-forge/noarch::cufflinks-py-0.17.3-py_0
#   ipykernel          conda-forge/noarch::ipykernel-6.15.1-pyh025b116_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.20.3-py39hc2deb75_0
#   pathspec           conda-forge/noarch::pathspec-0.9.0-pyhd8ed1ab_0
#   platformdirs       conda-forge/noarch::platformdirs-2.5.2-pyhd8ed1ab_1
#   plotly             conda-forge/noarch::plotly-5.10.0-pyhd8ed1ab_0
#   python-cufflinks   conda-forge/noarch::python-cufflinks-0.17.3-py_0
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#   retrying           conda-forge/noarch::retrying-1.3.3-py_2
#   scikit-learn       pkgs/main/win-64::scikit-learn-1.1.1-py39hd77b12b_0
#   tenacity           conda-forge/noarch::tenacity-8.0.1-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.10.26~ --> conda-forge::ca-certificates-2022.6.15-h5b45459_0
#   certifi            pkgs/main::certifi-2021.10.8-py39haa9~ --> conda-forge::certifi-2022.6.15-py39hcbf5309_0
#   conda              pkgs/main::conda-4.10.3-py39haa95532_0 --> conda-forge::conda-4.12.0-py39hcbf5309_0
#   openssl              pkgs/main::openssl-1.1.1l-h2bbff1b_0 --> conda-forge::openssl-1.1.1q-h8ffe710_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.11-py39_0 --> custom-py39_1
#
#
#
# Downloading and Extracting Packages
#
# scikit-learn-1.1.1   | 5.5 MB    |            |   0%
# scikit-learn-1.1.1   | 5.5 MB    |            |   0%
# scikit-learn-1.1.1   | 5.5 MB    | #6         |  16%
# scikit-learn-1.1.1   | 5.5 MB    | ###8       |  39%
# scikit-learn-1.1.1   | 5.5 MB    | ######1    |  61%
# scikit-learn-1.1.1   | 5.5 MB    | ########4  |  84%
# scikit-learn-1.1.1   | 5.5 MB    | ########## | 100%
#
# chart-studio-1.1.0   | 51 KB     |            |   0%
# chart-studio-1.1.0   | 51 KB     | ###1       |  32%
# chart-studio-1.1.0   | 51 KB     | ########## | 100%
#
# colorlover-0.3.0     | 12 KB     |            |   0%
# colorlover-0.3.0     | 12 KB     | ########## | 100%
#
# cufflinks-py-0.17.3  | 4 KB      |            |   0%
# cufflinks-py-0.17.3  | 4 KB      | ########## | 100%
#
# ipykernel-6.15.1     | 96 KB     |            |   0%
# ipykernel-6.15.1     | 96 KB     | ########## | 100%
# ipykernel-6.15.1     | 96 KB     | ########## | 100%
#
# plotly-5.10.0        | 7.0 MB    |            |   0%
# plotly-5.10.0        | 7.0 MB    | 6          |   7%
# plotly-5.10.0        | 7.0 MB    | ##         |  21%
# plotly-5.10.0        | 7.0 MB    | ###2       |  33%
# plotly-5.10.0        | 7.0 MB    | #####1     |  51%
# plotly-5.10.0        | 7.0 MB    | ######8    |  69%
# plotly-5.10.0        | 7.0 MB    | ########6  |  86%
# plotly-5.10.0        | 7.0 MB    | ########## | 100%
#
# conda-4.12.0         | 1.0 MB    |            |   0%
# conda-4.12.0         | 1.0 MB    | ######4    |  65%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
#
# _anaconda_depends-20 | 7 KB      |            |   0%
# _anaconda_depends-20 | 7 KB      | ########## | 100%
#
# anaconda-custom      | 4 KB      |            |   0%
# anaconda-custom      | 4 KB      | ########## | 100%
#
# certifi-2022.6.15    | 155 KB    |            |   0%
# certifi-2022.6.15    | 155 KB    | ########## | 100%
#
# openssl-1.1.1q       | 5.8 MB    |            |   0%
# openssl-1.1.1q       | 5.8 MB    | #4         |  15%
# openssl-1.1.1q       | 5.8 MB    | ###6       |  36%
# openssl-1.1.1q       | 5.8 MB    | #####7     |  58%
# openssl-1.1.1q       | 5.8 MB    | #######9   |  79%
# openssl-1.1.1q       | 5.8 MB    | ########## | 100%
# openssl-1.1.1q       | 5.8 MB    | ########## | 100%
#
# retrying-1.3.3       | 11 KB     |            |   0%
# retrying-1.3.3       | 11 KB     | ########## | 100%
#
# tomli-2.0.1          | 16 KB     |            |   0%
# tomli-2.0.1          | 16 KB     | ########## | 100%
#
# platformdirs-2.5.2   | 16 KB     |            |   0%
# platformdirs-2.5.2   | 16 KB     | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# python-cufflinks-0.1 | 59 KB     |            |   0%
# python-cufflinks-0.1 | 59 KB     | ########## | 100%
#
# tenacity-8.0.1       | 21 KB     |            |   0%
# tenacity-8.0.1       | 21 KB     | ########## | 100%
#
# black-22.6.0         | 295 KB    |            |   0%
# black-22.6.0         | 295 KB    | ########## | 100%
# black-22.6.0         | 295 KB    | ########## | 100%
#
# click-8.1.3          | 146 KB    |            |   0%
# click-8.1.3          | 146 KB    | ########## | 100%
# click-8.1.3          | 146 KB    | ########## | 100%
#
# ca-certificates-2022 | 188 KB    |            |   0%
# ca-certificates-2022 | 188 KB    | ########## | 100%
#
# pathspec-0.9.0       | 31 KB     |            |   0%
# pathspec-0.9.0       | 31 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Windows 64-bit packages of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.11=py39_0
#   - defaults/win-64::astropy==4.3.1=py39hc7d831d_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_0
#   - defaults/win-64::bokeh==2.4.1=py39haa95532_0
#   - defaults/win-64::bottleneck==1.3.2=py39h7cc1a96_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/win-64::daal4py==2021.3.0=py39h757b272_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/win-64::distributed==2021.10.0=py39haa95532_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/win-64::h5py==3.2.1=py39h3de5c98_0
#   - defaults/win-64::imagecodecs==2021.8.26=py39ha1f97ea_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/win-64::jupyter==1.0.0=py39haa95532_7
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_console==6.4.0=pyhd3eb1b0_0
#   - defaults/win-64::matplotlib==3.4.3=py39haa95532_0
#   - defaults/win-64::matplotlib-base==3.4.3=py39h49ac443_0
#   - defaults/win-64::mkl_fft==1.3.1=py39h277e83a_0
#   - defaults/win-64::mkl_random==1.2.2=py39hf11a4ad_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/win-64::notebook==6.4.5=py39haa95532_0
#   - defaults/win-64::numba==0.54.1=py39hf11a4ad_0
#   - defaults/win-64::numexpr==2.7.3=py39hb80d3ca_1
#   - defaults/win-64::numpy==1.20.3=py39ha4e8547_0
#   - defaults/win-64::pandas==1.3.4=py39h6214cd6_0
#   - defaults/win-64::patsy==0.5.2=py39haa95532_0
#   - defaults/win-64::pyerfa==2.0.0=py39h2bbff1b_0
#   - defaults/win-64::pytables==3.6.1=py39h56d22b6_1
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/win-64::pywavelets==1.1.1=py39h080aedc_4
#   - defaults/noarch::qtconsole==5.1.1=pyhd3eb1b0_0
#   - defaults/win-64::scikit-image==0.18.3=py39hf11a4ad_0
#   - defaults/win-64::scikit-learn-intelex==2021.3.0=py39haa95532_0
#   - defaults/win-64::scipy==1.7.1=py39hbe87c03_2
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/win-64::spyder==5.1.5=py39haa95532_1
#   - defaults/win-64::spyder-kernels==2.1.3=py39haa95532_0
#   - defaults/win-64::statsmodels==0.12.2=py39h2bbff1b_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/win-64::widgetsnbextension==3.5.1=py39haa95532_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.11=py39_0
#   - defaults/win-64::astropy==4.3.1=py39hc7d831d_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_0
#   - defaults/win-64::bokeh==2.4.1=py39haa95532_0
#   - defaults/win-64::bottleneck==1.3.2=py39h7cc1a96_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/win-64::daal4py==2021.3.0=py39h757b272_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/win-64::distributed==2021.10.0=py39haa95532_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/win-64::h5py==3.2.1=py39h3de5c98_0
#   - defaults/win-64::imagecodecs==2021.8.26=py39ha1f97ea_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/win-64::jupyter==1.0.0=py39haa95532_7
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_console==6.4.0=pyhd3eb1b0_0
#   - defaults/win-64::matplotlib==3.4.3=py39haa95532_0
#   - defaults/win-64::matplotlib-base==3.4.3=py39h49ac443_0
#   - defaults/win-64::mkl_fft==1.3.1=py39h277e83a_0
#   - defaults/win-64::mkl_random==1.2.2=py39hf11a4ad_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/win-64::notebook==6.4.5=py39haa95532_0
#   - defaults/win-64::numba==0.54.1=py39hf11a4ad_0
#   - defaults/win-64::numexpr==2.7.3=py39hb80d3ca_1
#   - defaults/win-64::numpy==1.20.3=py39ha4e8547_0
#   - defaults/win-64::pandas==1.3.4=py39h6214cd6_0
#   - defaults/win-64::patsy==0.5.2=py39haa95532_0
#   - defaults/win-64::pyerfa==2.0.0=py39h2bbff1b_0
#   - defaults/win-64::pytables==3.6.1=py39h56d22b6_1
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/win-64::pywavelets==1.1.1=py39h080aedc_4
#   - defaults/noarch::qtconsole==5.1.1=pyhd3eb1b0_0
#   - defaults/win-64::scikit-image==0.18.3=py39hf11a4ad_0
#   - defaults/win-64::scikit-learn-intelex==2021.3.0=py39haa95532_0
#   - defaults/win-64::scipy==1.7.1=py39hbe87c03_2
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/win-64::spyder==5.1.5=py39haa95532_1
#   - defaults/win-64::spyder-kernels==2.1.3=py39haa95532_0
#   - defaults/win-64::statsmodels==0.12.2=py39h2bbff1b_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/win-64::widgetsnbextension==3.5.1=py39haa95532_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.05  |           py39_0           7 KB
#     aiohttp-3.8.1              |   py39h2bbff1b_1         496 KB
#     aiosignal-1.2.0            |     pyhd3eb1b0_0          12 KB
#     anaconda-client-1.10.0     |   py39haa95532_0         166 KB
#     anaconda-project-0.11.1    |   py39haa95532_0         511 KB
#     anyio-3.5.0                |   py39haa95532_0         167 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py39h2bbff1b_0          36 KB
#     arrow-1.2.2                |     pyhd3eb1b0_0          92 KB
#     astropy-5.1                |   py39h080aedc_0         6.4 MB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     async-timeout-4.0.1        |     pyhd3eb1b0_0          10 KB
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     automat-20.2.0             |             py_0          31 KB
#     autopep8-1.6.0             |     pyhd3eb1b0_0          42 KB
#     backports-1.1              |     pyhd3eb1b0_0           4 KB
#     bcrypt-3.2.0               |   py39h2bbff1b_1          37 KB
#     beautifulsoup4-4.11.1      |   py39haa95532_0         190 KB
#     bitarray-2.5.1             |   py39h2bbff1b_0         157 KB
#     bkcharts-0.2               |   py39haa95532_1         132 KB
#     black-22.6.0               |   py39haa95532_0         244 KB
#     bleach-4.1.0               |     pyhd3eb1b0_0         123 KB
#     bokeh-2.4.3                |   py39haa95532_0         7.6 MB
#     boto3-1.24.28              |   py39haa95532_0         114 KB
#     botocore-1.27.28           |   py39haa95532_0         4.6 MB
#     bottleneck-1.3.5           |   py39h080aedc_0         106 KB
#     brotli-1.0.9               |       h2bbff1b_7          18 KB
#     brotli-bin-1.0.9           |       h2bbff1b_7          19 KB
#     ca-certificates-2022.07.19 |       haa95532_0         123 KB
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB
#     certifi-2022.6.15          |   py39haa95532_0         153 KB
#     cffi-1.15.1                |   py39h2bbff1b_0         218 KB
#     cfitsio-3.470              |       h2bbff1b_7         518 KB
#     click-8.0.4                |   py39haa95532_0         155 KB
#     colorama-0.4.5             |   py39haa95532_0          28 KB
#     colorcet-3.0.0             |   py39haa95532_0         1.8 MB
#     conda-4.14.0               |   py39haa95532_0         937 KB
#     conda-content-trust-0.1.3  |   py39haa95532_0          86 KB
#     conda-package-handling-1.8.1|   py39h8cc25b3_0         729 KB
#     conda-repo-cli-1.0.5       |   py39haa95532_0         122 KB
#     constantly-15.1.0          |     pyh2b92418_0          10 KB
#     cookiecutter-1.7.3         |     pyhd3eb1b0_0          79 KB
#     cryptography-37.0.1        |   py39h21b164f_0         977 KB
#     cssselect-1.1.0            |     pyhd3eb1b0_0          18 KB
#     curl-7.84.0                |       h2bbff1b_0         142 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     cython-0.29.30             |   py39hd77b12b_0         1.7 MB
#     daal4py-2021.5.0           |   py39h8cb3d55_0         7.9 MB
#     dal-2021.5.0               |     haa95532_796        23.2 MB
#     dask-2022.7.0              |   py39haa95532_0          20 KB
#     dask-core-2022.7.0         |   py39haa95532_0         1.7 MB
#     datashader-0.14.1          |   py39haa95532_0        16.5 MB
#     datashape-0.5.4            |   py39haa95532_1         103 KB
#     debugpy-1.5.1              |   py39hd77b12b_0         2.6 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     distributed-2022.7.0       |   py39haa95532_0         1.1 MB
#     docutils-0.18.1            |   py39haa95532_3         666 KB
#     entrypoints-0.4            |   py39haa95532_0          17 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     filelock-3.6.0             |     pyhd3eb1b0_0          12 KB
#     frozenlist-1.2.0           |   py39h2bbff1b_0          77 KB
#     fsspec-2022.7.1            |   py39haa95532_0         211 KB
#     gensim-4.1.2               |   py39hd77b12b_0        18.3 MB
#     google-api-core-2.2.2      |     pyhd3eb1b0_0          69 KB
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB
#     google-cloud-core-2.2.2    |     pyhd3eb1b0_0          26 KB
#     google-cloud-storage-1.43.0|   py39haa95532_0         120 KB
#     google-crc32c-1.1.2        |   py39h2bbff1b_0          25 KB
#     google-resumable-media-1.3.1|     pyhd3eb1b0_1          41 KB
#     googleapis-common-protos-1.56.4|   py39haa95532_0         131 KB
#     grpcio-1.42.0              |   py39hc60d5dd_0         1.9 MB
#     h5py-3.7.0                 |   py39h3de5c98_0         823 KB
#     hdf5-1.10.6                |       h1756f20_1         7.9 MB
#     holoviews-1.15.0           |   py39haa95532_0         4.0 MB
#     hvplot-0.8.0               |   py39haa95532_0         3.0 MB
#     hyperlink-21.0.0           |     pyhd3eb1b0_0          70 KB
#     idna-3.3                   |     pyhd3eb1b0_0          49 KB
#     imageio-2.19.3             |   py39haa95532_0         3.3 MB
#     imagesize-1.4.1            |   py39haa95532_0          14 KB
#     importlib-metadata-4.11.3  |   py39haa95532_0          41 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     incremental-21.3.0         |     pyhd3eb1b0_0          17 KB
#     intake-0.6.5               |     pyhd3eb1b0_0         178 KB
#     ipykernel-6.9.1            |   py39haa95532_0         200 KB
#     ipython-8.4.0              |   py39haa95532_0        1009 KB
#     itemadapter-0.3.0          |     pyhd3eb1b0_0          13 KB
#     itemloaders-1.0.4          |     pyhd3eb1b0_1          14 KB
#     jedi-0.18.1                |   py39haa95532_1         982 KB
#     jinja2-time-0.2.0          |     pyhd3eb1b0_3           9 KB
#     jmespath-0.10.0            |     pyhd3eb1b0_0          22 KB
#     jpeg-9e                    |       h2bbff1b_0         292 KB
#     jq-1.6                     |       haa95532_1         992 KB
#     jsonschema-4.4.0           |   py39haa95532_0         139 KB
#     jupyter-1.0.0              |   py39haa95532_8           7 KB
#     jupyter_core-4.10.0        |   py39haa95532_0          96 KB
#     jupyter_server-1.18.1      |   py39haa95532_0         372 KB
#     jupyterlab-3.4.4           |   py39haa95532_0         3.8 MB
#     jupyterlab_server-2.10.3   |     pyhd3eb1b0_1          48 KB
#     keyring-23.4.0             |   py39haa95532_0          72 KB
#     kiwisolver-1.4.2           |   py39hd77b12b_0          58 KB
#     libbrotlicommon-1.0.9      |       h2bbff1b_7          71 KB
#     libbrotlidec-1.0.9         |       h2bbff1b_7          30 KB
#     libbrotlienc-1.0.9         |       h2bbff1b_7         233 KB
#     libcrc32c-1.1.1            |       ha925a31_2          24 KB
#     libcurl-7.84.0             |       h86230a5_0         300 KB
#     libiconv-1.16              |       h2bbff1b_2         651 KB
#     liblief-0.11.5             |       hd77b12b_1         2.1 MB
#     libprotobuf-3.20.1         |       h23ce68f_0         2.0 MB
#     libsodium-1.0.18           |       h62dcd97_0         477 KB
#     libssh2-1.10.0             |       hcd4344a_0         222 KB
#     libtiff-4.4.0              |       h8a3f274_0         773 KB
#     libwebp-1.2.2              |       h2bbff1b_0         658 KB
#     libxml2-2.9.14             |       h0ad7f3c_0         1.5 MB
#     libxslt-1.1.35             |       h2bbff1b_0         407 KB
#     llvmlite-0.38.0            |   py39h23ce68f_0        13.3 MB
#     locket-1.0.0               |   py39haa95532_0          13 KB
#     lxml-4.9.1                 |   py39h1985fb9_0         936 KB
#     lz4-3.1.3                  |   py39h2bbff1b_0          96 KB
#     markdown-3.3.4             |   py39haa95532_0         144 KB
#     markupsafe-2.0.1           |   py39h2bbff1b_0          24 KB
#     matplotlib-3.5.1           |   py39haa95532_1          29 KB
#     matplotlib-base-3.5.1      |   py39hd77b12b_1         5.6 MB
#     mccabe-0.6.1               |   py39haa95532_2          15 KB
#     msgpack-python-1.0.3       |   py39h59b6b97_0          75 KB
#     multidict-5.1.0            |   py39h2bbff1b_2          61 KB
#     mypy_extensions-0.4.3      |   py39haa95532_1          10 KB
#     nbclassic-0.3.5            |     pyhd3eb1b0_0          22 KB
#     nbclient-0.5.13            |   py39haa95532_0         108 KB
#     nbconvert-6.4.4            |   py39haa95532_0         517 KB
#     nbformat-5.3.0             |   py39haa95532_0         146 KB
#     nest-asyncio-1.5.5         |   py39haa95532_0          16 KB
#     networkx-2.8.4             |   py39haa95532_0         2.2 MB
#     nltk-3.7                   |     pyhd3eb1b0_0        1010 KB
#     nose-1.3.7                 |  pyhd3eb1b0_1008         142 KB
#     notebook-6.4.12            |   py39haa95532_0         4.6 MB
#     numba-0.55.1               |   py39hf11a4ad_0         3.4 MB
#     numexpr-2.8.3              |   py39hb80d3ca_0         119 KB
#     numpy-1.21.5               |   py39h7a0a035_3          25 KB
#     numpy-base-1.21.5          |   py39hca35cd5_3         4.4 MB
#     numpydoc-1.4.0             |   py39haa95532_0          86 KB
#     openpyxl-3.0.10            |   py39h2bbff1b_0         468 KB
#     openssl-1.1.1q             |       h2bbff1b_0         4.8 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pandas-1.4.3               |   py39hd77b12b_0         8.7 MB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     panel-0.13.1               |   py39haa95532_0        11.0 MB
#     param-1.12.0               |     pyhd3eb1b0_0          75 KB
#     paramiko-2.8.1             |     pyhd3eb1b0_0         139 KB
#     parsel-1.6.0               |   py39haa95532_0         351 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     partd-1.2.0                |     pyhd3eb1b0_1          18 KB
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB
#     pathspec-0.9.0             |   py39haa95532_0          46 KB
#     patsy-0.5.2                |   py39haa95532_1         276 KB
#     pep8-1.7.1                 |   py39haa95532_1          69 KB
#     pillow-9.2.0               |   py39hdc2b20a_1         908 KB
#     pip-22.1.2                 |   py39haa95532_0         2.5 MB
#     pkginfo-1.8.2              |     pyhd3eb1b0_0          27 KB
#     platformdirs-2.4.0         |     pyhd3eb1b0_0          16 KB
#     plotly-5.9.0               |   py39haa95532_0         4.1 MB
#     pluggy-1.0.0               |   py39haa95532_1          29 KB
#     prometheus_client-0.14.1   |   py39haa95532_0          89 KB
#     protego-0.1.16             |             py_0         2.2 MB
#     protobuf-3.20.1            |   py39hd77b12b_0         231 KB
#     psutil-5.9.0               |   py39h2bbff1b_0         349 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     py-1.11.0                  |     pyhd3eb1b0_0          76 KB
#     py-lief-0.11.5             |   py39hd77b12b_1         1.7 MB
#     pyasn1-0.4.8               |     pyhd3eb1b0_0          54 KB
#     pyasn1-modules-0.2.8       |             py_0          72 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     pyct-0.4.8                 |   py39haa95532_1          45 KB
#     pycurl-7.45.1              |   py39hcd4344a_0          71 KB
#     pydispatcher-2.0.5         |   py39haa95532_2          20 KB
#     pygments-2.11.2            |     pyhd3eb1b0_0         759 KB
#     pyhamcrest-2.0.2           |     pyhd3eb1b0_2          31 KB
#     pyjwt-2.4.0                |   py39haa95532_0          38 KB
#     pynacl-1.5.0               |   py39h8cc25b3_0         1.2 MB
#     pyodbc-4.0.34              |   py39hd77b12b_0          64 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     pytest-7.1.2               |   py39haa95532_0         479 KB
#     python-fastjsonschema-2.15.1|     pyhd3eb1b0_0          29 KB
#     python-snappy-0.6.0        |   py39hd77b12b_3          31 KB
#     pytz-2022.1                |   py39haa95532_0         195 KB
#     pyviz_comms-2.0.2          |     pyhd3eb1b0_0          23 KB
#     pywavelets-1.3.0           |   py39h2bbff1b_0         3.5 MB
#     pywin32-302                |   py39h2bbff1b_2         5.6 MB
#     pywinpty-2.0.2             |   py39h5da7b33_0         200 KB
#     pyzmq-23.2.0               |   py39hd77b12b_0         404 KB
#     qtawesome-1.0.3            |     pyhd3eb1b0_0         761 KB
#     qtconsole-5.3.1            |   py39haa95532_1         192 KB
#     qtpy-2.0.1                 |     pyhd3eb1b0_0          40 KB
#     queuelib-1.5.0             |   py39haa95532_0         259 KB
#     regex-2022.7.9             |   py39h2bbff1b_0         307 KB
#     requests-2.28.1            |   py39haa95532_0          99 KB
#     requests-file-1.5.1        |     pyhd3eb1b0_0           8 KB
#     retrying-1.3.3             |     pyhd3eb1b0_2          14 KB
#     rope-0.22.0                |     pyhd3eb1b0_0         129 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     s3transfer-0.6.0           |   py39haa95532_0         110 KB
#     scikit-image-0.19.2        |   py39hf11a4ad_0         9.5 MB
#     scikit-learn-intelex-2021.5.0|   py39haa95532_0          69 KB
#     scipy-1.7.3                |   py39h0a974cb_0        13.9 MB
#     scrapy-2.6.2               |   py39haa95532_0         387 KB
#     service_identity-18.1.0    |     pyhd3eb1b0_1          13 KB
#     setuptools-63.4.1          |   py39haa95532_0         1.0 MB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     smart_open-5.2.1           |   py39haa95532_0          81 KB
#     snappy-1.1.9               |       h6c2663c_0         2.2 MB
#     snowballstemmer-2.2.0      |     pyhd3eb1b0_0          61 KB
#     soupsieve-2.3.1            |     pyhd3eb1b0_0          34 KB
#     sphinx-5.0.2               |   py39haa95532_0         1.7 MB
#     sqlalchemy-1.4.39          |   py39h2bbff1b_0         1.9 MB
#     sqlite-3.39.2              |       h2bbff1b_0         805 KB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     statsmodels-0.13.2         |   py39h2bbff1b_0         8.3 MB
#     sympy-1.10.1               |   py39haa95532_0         9.5 MB
#     tabulate-0.8.10            |   py39haa95532_0          62 KB
#     tbb-2021.5.0               |       h59b6b97_0         149 KB
#     tbb4py-2021.5.0            |   py39h59b6b97_0          76 KB
#     tenacity-8.0.1             |   py39haa95532_1          34 KB
#     terminado-0.13.1           |   py39haa95532_0          31 KB
#     testpath-0.6.0             |   py39haa95532_0          85 KB
#     tk-8.6.12                  |       h2bbff1b_0         3.1 MB
#     tldextract-3.2.0           |     pyhd3eb1b0_0          81 KB
#     tomli-2.0.1                |   py39haa95532_0          25 KB
#     toolz-0.11.2               |     pyhd3eb1b0_0          49 KB
#     tqdm-4.64.0                |   py39haa95532_0         155 KB
#     traitlets-5.1.1            |     pyhd3eb1b0_0          84 KB
#     twisted-22.2.0             |   py39h2bbff1b_1         4.2 MB
#     twisted-iocpsupport-1.0.2  |   py39h2bbff1b_0          46 KB
#     typing-extensions-4.3.0    |   py39haa95532_0           9 KB
#     typing_extensions-4.3.0    |   py39haa95532_0          42 KB
#     tzdata-2022a               |       hda174b7_0         109 KB
#     ujson-5.4.0                |   py39hd77b12b_0          44 KB
#     urllib3-1.26.11            |   py39haa95532_0         184 KB
#     w3lib-1.21.0               |     pyhd3eb1b0_0          22 KB
#     watchdog-2.1.6             |   py39haa95532_0         110 KB
#     websocket-client-0.58.0    |   py39haa95532_4          69 KB
#     werkzeug-2.0.3             |     pyhd3eb1b0_0         221 KB
#     wheel-0.37.1               |     pyhd3eb1b0_0          33 KB
#     widgetsnbextension-3.5.2   |   py39haa95532_0         646 KB
#     xarray-0.20.1              |     pyhd3eb1b0_1         563 KB
#     xlsxwriter-3.0.3           |     pyhd3eb1b0_0         113 KB
#     xz-5.2.5                   |       h8cc25b3_1         246 KB
#     yarl-1.6.3                 |   py39h2bbff1b_0         153 KB
#     zeromq-4.3.4               |       hd77b12b_0         4.2 MB
#     zict-2.1.0                 |   py39haa95532_0          20 KB
#     zipp-3.8.0                 |   py39haa95532_0          20 KB
#     zlib-1.2.12                |       h8cc25b3_2         116 KB
#     ------------------------------------------------------------
#                                            Total:       295.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohttp            pkgs/main/win-64::aiohttp-3.8.1-py39h2bbff1b_1
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ pkgs/main/win-64::argon2-cffi-bindings-21.2.0-py39h2bbff1b_0
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   async-timeout      pkgs/main/noarch::async-timeout-4.0.1-pyhd3eb1b0_0
#   automat            pkgs/main/noarch::automat-20.2.0-py_0
#   boto3              pkgs/main/win-64::boto3-1.24.28-py39haa95532_0
#   botocore           pkgs/main/win-64::botocore-1.27.28-py39haa95532_0
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_7
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   colorcet           pkgs/main/win-64::colorcet-3.0.0-py39haa95532_0
#   constantly         pkgs/main/noarch::constantly-15.1.0-pyh2b92418_0
#   cssselect          pkgs/main/noarch::cssselect-1.1.0-pyhd3eb1b0_0
#   datashader         pkgs/main/win-64::datashader-0.14.1-py39haa95532_0
#   datashape          pkgs/main/win-64::datashape-0.5.4-py39haa95532_1
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   frozenlist         pkgs/main/win-64::frozenlist-1.2.0-py39h2bbff1b_0
#   gensim             pkgs/main/win-64::gensim-4.1.2-py39hd77b12b_0
#   google-api-core    pkgs/main/noarch::google-api-core-2.2.2-pyhd3eb1b0_0
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-cloud-core  pkgs/main/noarch::google-cloud-core-2.2.2-pyhd3eb1b0_0
#   google-cloud-stor~ pkgs/main/win-64::google-cloud-storage-1.43.0-py39haa95532_0
#   google-crc32c      pkgs/main/win-64::google-crc32c-1.1.2-py39h2bbff1b_0
#   google-resumable-~ pkgs/main/noarch::google-resumable-media-1.3.1-pyhd3eb1b0_1
#   googleapis-common~ pkgs/main/win-64::googleapis-common-protos-1.56.4-py39haa95532_0
#   grpcio             pkgs/main/win-64::grpcio-1.42.0-py39hc60d5dd_0
#   holoviews          pkgs/main/win-64::holoviews-1.15.0-py39haa95532_0
#   hvplot             pkgs/main/win-64::hvplot-0.8.0-py39haa95532_0
#   hyperlink          pkgs/main/noarch::hyperlink-21.0.0-pyhd3eb1b0_0
#   incremental        pkgs/main/noarch::incremental-21.3.0-pyhd3eb1b0_0
#   intake             pkgs/main/noarch::intake-0.6.5-pyhd3eb1b0_0
#   itemadapter        pkgs/main/noarch::itemadapter-0.3.0-pyhd3eb1b0_0
#   itemloaders        pkgs/main/noarch::itemloaders-1.0.4-pyhd3eb1b0_1
#   jmespath           pkgs/main/noarch::jmespath-0.10.0-pyhd3eb1b0_0
#   jq                 pkgs/main/win-64::jq-1.6-haa95532_1
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_7
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_7
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_7
#   libcrc32c          pkgs/main/win-64::libcrc32c-1.1.1-ha925a31_2
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.20.1-h23ce68f_0
#   libsodium          pkgs/main/win-64::libsodium-1.0.18-h62dcd97_0
#   lz4                pkgs/main/win-64::lz4-3.1.3-py39h2bbff1b_0
#   markdown           pkgs/main/win-64::markdown-3.3.4-py39haa95532_0
#   multidict          pkgs/main/win-64::multidict-5.1.0-py39h2bbff1b_2
#   panel              pkgs/main/win-64::panel-0.13.1-py39haa95532_0
#   param              pkgs/main/noarch::param-1.12.0-pyhd3eb1b0_0
#   parsel             pkgs/main/win-64::parsel-1.6.0-py39haa95532_0
#   pathlib            pkgs/main/noarch::pathlib-1.0.1-pyhd3eb1b0_1
#   protego            pkgs/main/noarch::protego-0.1.16-py_0
#   protobuf           pkgs/main/win-64::protobuf-3.20.1-py39hd77b12b_0
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   pyct               pkgs/main/win-64::pyct-0.4.8-py39haa95532_1
#   pydispatcher       pkgs/main/win-64::pydispatcher-2.0.5-py39haa95532_2
#   pyhamcrest         pkgs/main/noarch::pyhamcrest-2.0.2-pyhd3eb1b0_2
#   python-fastjsonsc~ pkgs/main/noarch::python-fastjsonschema-2.15.1-pyhd3eb1b0_0
#   python-snappy      pkgs/main/win-64::python-snappy-0.6.0-py39hd77b12b_3
#   pyviz_comms        pkgs/main/noarch::pyviz_comms-2.0.2-pyhd3eb1b0_0
#   queuelib           pkgs/main/win-64::queuelib-1.5.0-py39haa95532_0
#   requests-file      pkgs/main/noarch::requests-file-1.5.1-pyhd3eb1b0_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   s3transfer         pkgs/main/win-64::s3transfer-0.6.0-py39haa95532_0
#   scrapy             pkgs/main/win-64::scrapy-2.6.2-py39haa95532_0
#   service_identity   pkgs/main/noarch::service_identity-18.1.0-pyhd3eb1b0_1
#   smart_open         pkgs/main/win-64::smart_open-5.2.1-py39haa95532_0
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   tabulate           pkgs/main/win-64::tabulate-0.8.10-py39haa95532_0
#   tldextract         pkgs/main/noarch::tldextract-3.2.0-pyhd3eb1b0_0
#   twisted            pkgs/main/win-64::twisted-22.2.0-py39h2bbff1b_1
#   twisted-iocpsuppo~ pkgs/main/win-64::twisted-iocpsupport-1.0.2-py39h2bbff1b_0
#   typing-extensions  pkgs/main/win-64::typing-extensions-4.3.0-py39haa95532_0
#   w3lib              pkgs/main/noarch::w3lib-1.21.0-pyhd3eb1b0_0
#   websocket-client   pkgs/main/win-64::websocket-client-0.58.0-py39haa95532_4
#   xarray             pkgs/main/noarch::xarray-0.20.1-pyhd3eb1b0_1
#   yarl               pkgs/main/win-64::yarl-1.6.3-py39h2bbff1b_0
#   zeromq             pkgs/main/win-64::zeromq-4.3.4-hd77b12b_0
#
# The following packages will be REMOVED:
#
#   argh-0.26.2-py39haa95532_0
#   asn1crypto-1.4.0-py_0
#   async_generator-1.10-pyhd3eb1b0_0
#   backports.shutil_get_terminal_size-1.0.0-pyhd3eb1b0_3
#   boto-2.49.0-py39haa95532_0
#   cached-property-1.5.2-py_0
#   contextlib2-0.6.0.post1-pyhd3eb1b0_0
#   fastcache-1.1.0-py39h196d8e1_0
#   get_terminal_size-1.0.0-h38e98db_0
#   gevent-21.8.0-py39h2bbff1b_1
#   html5lib-1.1-pyhd3eb1b0_0
#   krb5-1.19.2-h5b6d351_0
#   m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gmp-6.1.0-2
#   more-itertools-8.10.0-pyhd3eb1b0_0
#   path-16.0.0-py39haa95532_0
#   path.py-12.5.0-hd3eb1b0_0
#   pathlib2-2.3.6-py39haa95532_2
#   ply-3.11-py39haa95532_0
#   python_abi-3.9-2_cp39
#   simplegeneric-0.8.1-py39haa95532_2
#   singledispatch-3.7.0-pyhd3eb1b0_1001
#   sphinxcontrib-1.0-py39haa95532_1
#   sphinxcontrib-websupport-1.2.4-py_0
#   unicodecsv-0.14.1-py39haa95532_0
#   whichcraft-0.6.1-pyhd3eb1b0_0
#   xlwt-1.3.0-py39haa95532_0
#   zope.event-4.5.0-py39haa95532_0
#
# The following packages will be UPDATED:
#
#   _anaconda_depends                          2021.11-py39_0 --> 2022.05-py39_0
#   anaconda-client                      1.9.0-py39haa95532_0 --> 1.10.0-py39haa95532_0
#   anaconda-project   pkgs/main/noarch::anaconda-project-0.~ --> pkgs/main/win-64::anaconda-project-0.11.1-py39haa95532_0
#   anyio                                2.2.0-py39haa95532_2 --> 3.5.0-py39haa95532_0
#   argon2-cffi        pkgs/main/win-64::argon2-cffi-20.1.0-~ --> pkgs/main/noarch::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   arrow              pkgs/main/win-64::arrow-0.13.1-py39ha~ --> pkgs/main/noarch::arrow-1.2.2-pyhd3eb1b0_0
#   astropy                              4.3.1-py39hc7d831d_0 --> 5.1-py39h080aedc_0
#   attrs                                 21.2.0-pyhd3eb1b0_0 --> 21.4.0-pyhd3eb1b0_0
#   autopep8                               1.5.7-pyhd3eb1b0_0 --> 1.6.0-pyhd3eb1b0_0
#   backports                                1.0-pyhd3eb1b0_2 --> 1.1-pyhd3eb1b0_0
#   bcrypt                               3.2.0-py39h196d8e1_0 --> 3.2.0-py39h2bbff1b_1
#   beautifulsoup4     pkgs/main/noarch::beautifulsoup4-4.10~ --> pkgs/main/win-64::beautifulsoup4-4.11.1-py39haa95532_0
#   bitarray                             2.3.0-py39h2bbff1b_1 --> 2.5.1-py39h2bbff1b_0
#   bkcharts                               0.2-py39haa95532_0 --> 0.2-py39haa95532_1
#   bleach                                 4.0.0-pyhd3eb1b0_0 --> 4.1.0-pyhd3eb1b0_0
#   bokeh                                2.4.1-py39haa95532_0 --> 2.4.3-py39haa95532_0
#   bottleneck                           1.3.2-py39h7cc1a96_1 --> 1.3.5-py39h080aedc_0
#   brotli                                   1.0.9-ha925a31_2 --> 1.0.9-h2bbff1b_7
#   ca-certificates    conda-forge::ca-certificates-2022.6.1~ --> pkgs/main::ca-certificates-2022.07.19-haa95532_0
#   cffi                                1.14.6-py39h2bbff1b_0 --> 1.15.1-py39h2bbff1b_0
#   cfitsio                                  3.470-he774522_6 --> 3.470-h2bbff1b_7
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd~ --> pkgs/main/win-64::colorama-0.4.5-py39haa95532_0
#   conda              conda-forge::conda-4.12.0-py39hcbf530~ --> pkgs/main::conda-4.14.0-py39haa95532_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust~ --> pkgs/main/win-64::conda-content-trust-0.1.3-py39haa95532_0
#   conda-package-han~                   1.7.3-py39h8cc25b3_1 --> 1.8.1-py39h8cc25b3_0
#   conda-repo-cli     pkgs/main/noarch::conda-repo-cli-1.0.~ --> pkgs/main/win-64::conda-repo-cli-1.0.5-py39haa95532_0
#   cookiecutter                           1.7.2-pyhd3eb1b0_0 --> 1.7.3-pyhd3eb1b0_0
#   cryptography                         3.4.8-py39h71e12ea_0 --> 37.0.1-py39h21b164f_0
#   curl                                    7.78.0-h86230a5_0 --> 7.84.0-h2bbff1b_0
#   cycler             pkgs/main/win-64::cycler-0.10.0-py39h~ --> pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   cython                             0.29.24-py39h604cdb4_0 --> 0.29.30-py39hd77b12b_0
#   daal4py                           2021.3.0-py39h757b272_0 --> 2021.5.0-py39h8cb3d55_0
#   dal                                 2021.3.0-haa95532_564 --> 2021.5.0-haa95532_796
#   dask               pkgs/main/noarch::dask-2021.10.0-pyhd~ --> pkgs/main/win-64::dask-2022.7.0-py39haa95532_0
#   dask-core          pkgs/main/noarch::dask-core-2021.10.0~ --> pkgs/main/win-64::dask-core-2022.7.0-py39haa95532_0
#   debugpy                              1.4.1-py39hd77b12b_0 --> 1.5.1-py39hd77b12b_0
#   decorator                              5.1.0-pyhd3eb1b0_0 --> 5.1.1-pyhd3eb1b0_0
#   distributed                      2021.10.0-py39haa95532_0 --> 2022.7.0-py39haa95532_0
#   docutils                            0.17.1-py39haa95532_1 --> 0.18.1-py39haa95532_3
#   entrypoints                            0.3-py39haa95532_0 --> 0.4-py39haa95532_0
#   filelock                               3.3.1-pyhd3eb1b0_1 --> 3.6.0-pyhd3eb1b0_0
#   fsspec             pkgs/main/noarch::fsspec-2021.10.1-py~ --> pkgs/main/win-64::fsspec-2022.7.1-py39haa95532_0
#   h5py                                 3.2.1-py39h3de5c98_0 --> 3.7.0-py39h3de5c98_0
#   hdf5                                    1.10.6-h7ebc959_0 --> 1.10.6-h1756f20_1
#   idna                                     3.2-pyhd3eb1b0_0 --> 3.3-pyhd3eb1b0_0
#   imageio            pkgs/main/noarch::imageio-2.9.0-pyhd3~ --> pkgs/main/win-64::imageio-2.19.3-py39haa95532_0
#   imagesize          pkgs/main/noarch::imagesize-1.2.0-pyh~ --> pkgs/main/win-64::imagesize-1.4.1-py39haa95532_0
#   importlib-metadata                   4.8.1-py39haa95532_0 --> 4.11.3-py39haa95532_0
#   importlib_metadata                       4.8.1-hd3eb1b0_0 --> 4.11.3-hd3eb1b0_0
#   ipython                             7.29.0-py39hd4e2768_0 --> 8.4.0-py39haa95532_0
#   jedi                                0.18.0-py39haa95532_1 --> 0.18.1-py39haa95532_1
#   jinja2-time                            0.2.0-pyhd3eb1b0_2 --> 0.2.0-pyhd3eb1b0_3
#   jpeg                                        9d-h2bbff1b_0 --> 9e-h2bbff1b_0
#   jsonschema         pkgs/main/noarch::jsonschema-3.2.0-py~ --> pkgs/main/win-64::jsonschema-4.4.0-py39haa95532_0
#   jupyter                              1.0.0-py39haa95532_7 --> 1.0.0-py39haa95532_8
#   jupyter_core                         4.8.1-py39haa95532_0 --> 4.10.0-py39haa95532_0
#   jupyter_server                       1.4.1-py39haa95532_0 --> 1.18.1-py39haa95532_0
#   jupyterlab         pkgs/main/noarch::jupyterlab-3.2.1-py~ --> pkgs/main/win-64::jupyterlab-3.4.4-py39haa95532_0
#   jupyterlab_server                      2.8.2-pyhd3eb1b0_0 --> 2.10.3-pyhd3eb1b0_1
#   keyring                             23.1.0-py39haa95532_0 --> 23.4.0-py39haa95532_0
#   kiwisolver                           1.3.1-py39hd77b12b_0 --> 1.4.2-py39hd77b12b_0
#   libcurl                                 7.78.0-h86230a5_0 --> 7.84.0-h86230a5_0
#   libiconv                                  1.15-h1df5818_7 --> 1.16-h2bbff1b_2
#   liblief                                 0.10.1-hd77b12b_1 --> 0.11.5-hd77b12b_1
#   libssh2                                  1.9.0-h7a1dbc1_1 --> 1.10.0-hcd4344a_0
#   libtiff                                  4.2.0-hd0e1b90_0 --> 4.4.0-h8a3f274_0
#   libwebp                                  1.2.0-h2bbff1b_0 --> 1.2.2-h2bbff1b_0
#   libxml2                                 2.9.12-h0ad7f3c_0 --> 2.9.14-h0ad7f3c_0
#   libxslt                                 1.1.34-he774522_0 --> 1.1.35-h2bbff1b_0
#   llvmlite                            0.37.0-py39h23ce68f_1 --> 0.38.0-py39h23ce68f_0
#   locket                               0.2.1-py39haa95532_1 --> 1.0.0-py39haa95532_0
#   lxml                                 4.6.3-py39h9b66d53_0 --> 4.9.1-py39h1985fb9_0
#   markupsafe                           1.1.1-py39h2bbff1b_0 --> 2.0.1-py39h2bbff1b_0
#   matplotlib                           3.4.3-py39haa95532_0 --> 3.5.1-py39haa95532_1
#   matplotlib-base                      3.4.3-py39h49ac443_0 --> 3.5.1-py39hd77b12b_1
#   mccabe                               0.6.1-py39haa95532_1 --> 0.6.1-py39haa95532_2
#   msgpack-python                       1.0.2-py39h59b6b97_1 --> 1.0.3-py39h59b6b97_0
#   mypy_extensions                      0.4.3-py39haa95532_0 --> 0.4.3-py39haa95532_1
#   nbclassic                              0.2.6-pyhd3eb1b0_0 --> 0.3.5-pyhd3eb1b0_0
#   nbclient           pkgs/main/noarch::nbclient-0.5.3-pyhd~ --> pkgs/main/win-64::nbclient-0.5.13-py39haa95532_0
#   nbconvert                            6.1.0-py39haa95532_0 --> 6.4.4-py39haa95532_0
#   nbformat           pkgs/main/noarch::nbformat-5.1.3-pyhd~ --> pkgs/main/win-64::nbformat-5.3.0-py39haa95532_0
#   nest-asyncio       pkgs/main/noarch::nest-asyncio-1.5.1-~ --> pkgs/main/win-64::nest-asyncio-1.5.5-py39haa95532_0
#   networkx           pkgs/main/noarch::networkx-2.6.3-pyhd~ --> pkgs/main/win-64::networkx-2.8.4-py39haa95532_0
#   nltk                                   3.6.5-pyhd3eb1b0_0 --> 3.7-pyhd3eb1b0_0
#   nose                                1.3.7-pyhd3eb1b0_1006 --> 1.3.7-pyhd3eb1b0_1008
#   notebook                             6.4.5-py39haa95532_0 --> 6.4.12-py39haa95532_0
#   numba                               0.54.1-py39hf11a4ad_0 --> 0.55.1-py39hf11a4ad_0
#   numexpr                              2.7.3-py39hb80d3ca_1 --> 2.8.3-py39hb80d3ca_0
#   numpy                               1.20.3-py39ha4e8547_0 --> 1.21.5-py39h7a0a035_3
#   numpy-base                          1.20.3-py39hc2deb75_0 --> 1.21.5-py39hca35cd5_3
#   numpydoc           pkgs/main/noarch::numpydoc-1.1.0-pyhd~ --> pkgs/main/win-64::numpydoc-1.4.0-py39haa95532_0
#   openpyxl           pkgs/main/noarch::openpyxl-3.0.9-pyhd~ --> pkgs/main/win-64::openpyxl-3.0.10-py39h2bbff1b_0
#   packaging                               21.0-pyhd3eb1b0_0 --> 21.3-pyhd3eb1b0_0
#   pandas                               1.3.4-py39h6214cd6_0 --> 1.4.3-py39hd77b12b_0
#   pandocfilters      pkgs/main/win-64::pandocfilters-1.4.3~ --> pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   paramiko                                       2.7.2-py_0 --> 2.8.1-pyhd3eb1b0_0
#   parso                                  0.8.2-pyhd3eb1b0_0 --> 0.8.3-pyhd3eb1b0_0
#   partd                                  1.2.0-pyhd3eb1b0_0 --> 1.2.0-pyhd3eb1b0_1
#   patsy                                0.5.2-py39haa95532_0 --> 0.5.2-py39haa95532_1
#   pep8                                 1.7.1-py39haa95532_0 --> 1.7.1-py39haa95532_1
#   pillow                               8.4.0-py39hd45dc43_0 --> 9.2.0-py39hdc2b20a_1
#   pip                                 21.2.4-py39haa95532_0 --> 22.1.2-py39haa95532_0
#   pkginfo            pkgs/main/win-64::pkginfo-1.7.1-py39h~ --> pkgs/main/noarch::pkginfo-1.8.2-pyhd3eb1b0_0
#   pluggy                              0.13.1-py39haa95532_0 --> 1.0.0-py39haa95532_1
#   prometheus_client  pkgs/main/noarch::prometheus_client-0~ --> pkgs/main/win-64::prometheus_client-0.14.1-py39haa95532_0
#   psutil                               5.8.0-py39h2bbff1b_1 --> 5.9.0-py39h2bbff1b_0
#   py                                    1.10.0-pyhd3eb1b0_0 --> 1.11.0-pyhd3eb1b0_0
#   py-lief                             0.10.1-py39hd77b12b_1 --> 0.11.5-py39hd77b12b_1
#   pycparser                                       2.20-py_2 --> 2.21-pyhd3eb1b0_0
#   pycurl                              7.44.1-py39hcd4344a_1 --> 7.45.1-py39hcd4344a_0
#   pygments                              2.10.0-pyhd3eb1b0_0 --> 2.11.2-pyhd3eb1b0_0
#   pyjwt                                2.1.0-py39haa95532_0 --> 2.4.0-py39haa95532_0
#   pynacl                               1.4.0-py39hbd8134f_1 --> 1.5.0-py39h8cc25b3_0
#   pyodbc                              4.0.31-py39hd77b12b_0 --> 4.0.34-py39hd77b12b_0
#   pyopenssl                             21.0.0-pyhd3eb1b0_1 --> 22.0.0-pyhd3eb1b0_0
#   pytest                               6.2.4-py39haa95532_2 --> 7.1.2-py39haa95532_0
#   pytz               pkgs/main/noarch::pytz-2021.3-pyhd3eb~ --> pkgs/main/win-64::pytz-2022.1-py39haa95532_0
#   pywavelets                           1.1.1-py39h080aedc_4 --> 1.3.0-py39h2bbff1b_0
#   pywin32                                228-py39he774522_0 --> 302-py39h2bbff1b_2
#   pywinpty                             0.5.7-py39haa95532_0 --> 2.0.2-py39h5da7b33_0
#   pyzmq                               22.2.1-py39hd77b12b_1 --> 23.2.0-py39hd77b12b_0
#   qtawesome                              1.0.2-pyhd3eb1b0_0 --> 1.0.3-pyhd3eb1b0_0
#   qtconsole          pkgs/main/noarch::qtconsole-5.1.1-pyh~ --> pkgs/main/win-64::qtconsole-5.3.1-py39haa95532_1
#   qtpy                                  1.10.0-pyhd3eb1b0_0 --> 2.0.1-pyhd3eb1b0_0
#   regex                             2021.8.3-py39h2bbff1b_0 --> 2022.7.9-py39h2bbff1b_0
#   requests           pkgs/main/noarch::requests-2.26.0-pyh~ --> pkgs/main/win-64::requests-2.28.1-py39haa95532_0
#   rope                                  0.19.0-pyhd3eb1b0_0 --> 0.22.0-pyhd3eb1b0_0
#   scikit-image                        0.18.3-py39hf11a4ad_0 --> 0.19.2-py39hf11a4ad_0
#   scikit-learn-inte~                2021.3.0-py39haa95532_0 --> 2021.5.0-py39haa95532_0
#   scipy                                1.7.1-py39hbe87c03_2 --> 1.7.3-py39h0a974cb_0
#   setuptools                          58.0.4-py39haa95532_0 --> 63.4.1-py39haa95532_0
#   six                                   1.16.0-pyhd3eb1b0_0 --> 1.16.0-pyhd3eb1b0_1
#   snappy                                   1.1.8-h33f27b4_0 --> 1.1.9-h6c2663c_0
#   snowballstemmer                        2.1.0-pyhd3eb1b0_0 --> 2.2.0-pyhd3eb1b0_0
#   soupsieve                              2.2.1-pyhd3eb1b0_0 --> 2.3.1-pyhd3eb1b0_0
#   sphinx             pkgs/main/noarch::sphinx-4.2.0-pyhd3e~ --> pkgs/main/win-64::sphinx-5.0.2-py39haa95532_0
#   sqlalchemy                          1.4.22-py39h2bbff1b_0 --> 1.4.39-py39h2bbff1b_0
#   sqlite                                  3.36.0-h2bbff1b_0 --> 3.39.2-h2bbff1b_0
#   statsmodels                         0.12.2-py39h2bbff1b_0 --> 0.13.2-py39h2bbff1b_0
#   sympy                                  1.9-py39haa95532_0 --> 1.10.1-py39haa95532_0
#   tbb                                   2021.4.0-h59b6b97_0 --> 2021.5.0-h59b6b97_0
#   tbb4py                            2021.4.0-py39h59b6b97_0 --> 2021.5.0-py39h59b6b97_0
#   tenacity           conda-forge/noarch::tenacity-8.0.1-py~ --> pkgs/main/win-64::tenacity-8.0.1-py39haa95532_1
#   terminado                            0.9.4-py39haa95532_0 --> 0.13.1-py39haa95532_0
#   testpath           pkgs/main/noarch::testpath-0.5.0-pyhd~ --> pkgs/main/win-64::testpath-0.6.0-py39haa95532_0
#   tk                                      8.6.11-h2bbff1b_0 --> 8.6.12-h2bbff1b_0
#   toolz                                 0.11.1-pyhd3eb1b0_0 --> 0.11.2-pyhd3eb1b0_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb~ --> pkgs/main/win-64::tqdm-4.64.0-py39haa95532_0
#   traitlets                              5.1.0-pyhd3eb1b0_0 --> 5.1.1-pyhd3eb1b0_0
#   typing_extensions  pkgs/main/noarch::typing_extensions-3~ --> pkgs/main/win-64::typing_extensions-4.3.0-py39haa95532_0
#   tzdata                                   2021e-hda174b7_0 --> 2022a-hda174b7_0
#   ujson                                4.0.2-py39hd77b12b_0 --> 5.4.0-py39hd77b12b_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd~ --> pkgs/main/win-64::urllib3-1.26.11-py39haa95532_0
#   watchdog                             2.1.3-py39haa95532_0 --> 2.1.6-py39haa95532_0
#   werkzeug                               2.0.2-pyhd3eb1b0_0 --> 2.0.3-pyhd3eb1b0_0
#   wheel                                 0.37.0-pyhd3eb1b0_1 --> 0.37.1-pyhd3eb1b0_0
#   widgetsnbextension                   3.5.1-py39haa95532_0 --> 3.5.2-py39haa95532_0
#   xlsxwriter                             3.0.1-pyhd3eb1b0_0 --> 3.0.3-pyhd3eb1b0_0
#   xz                                       5.2.5-h62dcd97_0 --> 5.2.5-h8cc25b3_1
#   zict               pkgs/main/noarch::zict-2.0.0-pyhd3eb1~ --> pkgs/main/win-64::zict-2.1.0-py39haa95532_0
#   zipp               pkgs/main/noarch::zipp-3.6.0-pyhd3eb1~ --> pkgs/main/win-64::zipp-3.8.0-py39haa95532_0
#   zlib                                    1.2.11-h62dcd97_4 --> 1.2.12-h8cc25b3_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   black              conda-forge::black-22.6.0-py39hcbf530~ --> pkgs/main::black-22.6.0-py39haa95532_0
#   certifi            conda-forge::certifi-2022.6.15-py39hc~ --> pkgs/main::certifi-2022.6.15-py39haa95532_0
#   click              conda-forge::click-8.1.3-py39hcbf5309~ --> pkgs/main::click-8.0.4-py39haa95532_0
#   ipykernel          conda-forge/noarch::ipykernel-6.15.1-~ --> pkgs/main/win-64::ipykernel-6.9.1-py39haa95532_0
#   openssl            conda-forge::openssl-1.1.1q-h8ffe710_0 --> pkgs/main::openssl-1.1.1q-h2bbff1b_0
#   pathspec           conda-forge/noarch::pathspec-0.9.0-py~ --> pkgs/main/win-64::pathspec-0.9.0-py39haa95532_0
#   platformdirs       conda-forge::platformdirs-2.5.2-pyhd8~ --> pkgs/main::platformdirs-2.4.0-pyhd3eb1b0_0
#   plotly             conda-forge/noarch::plotly-5.10.0-pyh~ --> pkgs/main/win-64::plotly-5.9.0-py39haa95532_0
#   retrying                 conda-forge::retrying-1.3.3-py_2 --> pkgs/main::retrying-1.3.3-pyhd3eb1b0_2
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8~ --> pkgs/main/win-64::tomli-2.0.1-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# paramiko-2.8.1       | 139 KB    |            |   0%
# paramiko-2.8.1       | 139 KB    | #1         |  11%
# paramiko-2.8.1       | 139 KB    | ########## | 100%
#
# pycurl-7.45.1        | 71 KB     |            |   0%
# pycurl-7.45.1        | 71 KB     | ##2        |  23%
# pycurl-7.45.1        | 71 KB     | ########## | 100%
#
# jpeg-9e              | 292 KB    |            |   0%
# jpeg-9e              | 292 KB    | ########## | 100%
# jpeg-9e              | 292 KB    | ########## | 100%
#
# libxml2-2.9.14       | 1.5 MB    |            |   0%
# libxml2-2.9.14       | 1.5 MB    | #####3     |  53%
# libxml2-2.9.14       | 1.5 MB    | ########## | 100%
#
# pytest-7.1.2         | 479 KB    |            |   0%
# pytest-7.1.2         | 479 KB    | ########## | 100%
# pytest-7.1.2         | 479 KB    | ########## | 100%
#
# qtpy-2.0.1           | 40 KB     |            |   0%
# qtpy-2.0.1           | 40 KB     | ########## | 100%
# qtpy-2.0.1           | 40 KB     | ########## | 100%
#
# locket-1.0.0         | 13 KB     |            |   0%
# locket-1.0.0         | 13 KB     | ########## | 100%
#
# conda-4.14.0         | 937 KB    |            |   0%
# conda-4.14.0         | 937 KB    | ########5  |  85%
# conda-4.14.0         | 937 KB    | ########## | 100%
#
# decorator-5.1.1      | 12 KB     |            |   0%
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
# traitlets-5.1.1      | 84 KB     |            |   0%
# traitlets-5.1.1      | 84 KB     | ########## | 100%
#
# pure_eval-0.2.2      | 14 KB     |            |   0%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
#
# scipy-1.7.3          | 13.9 MB   |            |   0%
# scipy-1.7.3          | 13.9 MB   | 4          |   5%
# scipy-1.7.3          | 13.9 MB   | #3         |  14%
# scipy-1.7.3          | 13.9 MB   | ##2        |  23%
# scipy-1.7.3          | 13.9 MB   | ###1       |  32%
# scipy-1.7.3          | 13.9 MB   | ####       |  40%
# scipy-1.7.3          | 13.9 MB   | ####9      |  49%
# scipy-1.7.3          | 13.9 MB   | #####8     |  58%
# scipy-1.7.3          | 13.9 MB   | ######7    |  67%
# scipy-1.7.3          | 13.9 MB   | #######5   |  76%
# scipy-1.7.3          | 13.9 MB   | ########4  |  85%
# scipy-1.7.3          | 13.9 MB   | #########3 |  93%
# scipy-1.7.3          | 13.9 MB   | ########## | 100%
#
# dal-2021.5.0         | 23.2 MB   |            |   0%
# dal-2021.5.0         | 23.2 MB   |            |   1%
# dal-2021.5.0         | 23.2 MB   | 9          |  10%
# dal-2021.5.0         | 23.2 MB   | #5         |  15%
# dal-2021.5.0         | 23.2 MB   | ##         |  20%
# dal-2021.5.0         | 23.2 MB   | ##5        |  26%
# dal-2021.5.0         | 23.2 MB   | ###1       |  31%
# dal-2021.5.0         | 23.2 MB   | ###6       |  37%
# dal-2021.5.0         | 23.2 MB   | ####2      |  42%
# dal-2021.5.0         | 23.2 MB   | ####7      |  47%
# dal-2021.5.0         | 23.2 MB   | #####2     |  53%
# dal-2021.5.0         | 23.2 MB   | #####8     |  58%
# dal-2021.5.0         | 23.2 MB   | ######3    |  63%
# dal-2021.5.0         | 23.2 MB   | ######8    |  69%
# dal-2021.5.0         | 23.2 MB   | #######3   |  74%
# dal-2021.5.0         | 23.2 MB   | #######9   |  79%
# dal-2021.5.0         | 23.2 MB   | ########4  |  85%
# dal-2021.5.0         | 23.2 MB   | #########  |  90%
# dal-2021.5.0         | 23.2 MB   | #########5 |  95%
# dal-2021.5.0         | 23.2 MB   | ########## | 100%
#
# libprotobuf-3.20.1   | 2.0 MB    |            |   0%
# libprotobuf-3.20.1   | 2.0 MB    | ####3      |  44%
# libprotobuf-3.20.1   | 2.0 MB    | ########## | 100%
# libprotobuf-3.20.1   | 2.0 MB    | ########## | 100%
#
# pydispatcher-2.0.5   | 20 KB     |            |   0%
# pydispatcher-2.0.5   | 20 KB     | ########## | 100%
#
# networkx-2.8.4       | 2.2 MB    |            |   0%
# networkx-2.8.4       | 2.2 MB    | ###2       |  32%
# networkx-2.8.4       | 2.2 MB    | ########9  |  89%
# networkx-2.8.4       | 2.2 MB    | ########## | 100%
#
# imagesize-1.4.1      | 14 KB     |            |   0%
# imagesize-1.4.1      | 14 KB     | ########## | 100%
#
# panel-0.13.1         | 11.0 MB   |            |   0%
# panel-0.13.1         | 11.0 MB   | 8          |   9%
# panel-0.13.1         | 11.0 MB   | ##         |  20%
# panel-0.13.1         | 11.0 MB   | ###1       |  31%
# panel-0.13.1         | 11.0 MB   | ####2      |  43%
# panel-0.13.1         | 11.0 MB   | #####3     |  54%
# panel-0.13.1         | 11.0 MB   | ######4    |  65%
# panel-0.13.1         | 11.0 MB   | #######6   |  76%
# panel-0.13.1         | 11.0 MB   | ########7  |  88%
# panel-0.13.1         | 11.0 MB   | #########9 |  99%
# panel-0.13.1         | 11.0 MB   | ########## | 100%
#
# urllib3-1.26.11      | 184 KB    |            |   0%
# urllib3-1.26.11      | 184 KB    | ########## | 100%
# urllib3-1.26.11      | 184 KB    | ########## | 100%
#
# asttokens-2.0.5      | 20 KB     |            |   0%
# asttokens-2.0.5      | 20 KB     | ########## | 100%
#
# zeromq-4.3.4         | 4.2 MB    |            |   0%
# zeromq-4.3.4         | 4.2 MB    | ##2        |  22%
# zeromq-4.3.4         | 4.2 MB    | ####8      |  48%
# zeromq-4.3.4         | 4.2 MB    | #######7   |  78%
# zeromq-4.3.4         | 4.2 MB    | ########## | 100%
#
# lxml-4.9.1           | 936 KB    |            |   0%
# lxml-4.9.1           | 936 KB    | #########2 |  92%
# lxml-4.9.1           | 936 KB    | ########## | 100%
#
# itemloaders-1.0.4    | 14 KB     |            |   0%
# itemloaders-1.0.4    | 14 KB     | ########## | 100%
#
# setuptools-63.4.1    | 1.0 MB    |            |   0%
# setuptools-63.4.1    | 1.0 MB    | ########8  |  88%
# setuptools-63.4.1    | 1.0 MB    | ########## | 100%
#
# google-auth-2.6.0    | 83 KB     |            |   0%
# google-auth-2.6.0    | 83 KB     | ########## | 100%
#
# botocore-1.27.28     | 4.6 MB    |            |   0%
# botocore-1.27.28     | 4.6 MB    | #2         |  12%
# botocore-1.27.28     | 4.6 MB    | ####       |  41%
# botocore-1.27.28     | 4.6 MB    | ######7    |  67%
# botocore-1.27.28     | 4.6 MB    | #########3 |  94%
# botocore-1.27.28     | 4.6 MB    | ########## | 100%
#
# pyzmq-23.2.0         | 404 KB    |            |   0%
# pyzmq-23.2.0         | 404 KB    | ########## | 100%
# pyzmq-23.2.0         | 404 KB    | ########## | 100%
#
# retrying-1.3.3       | 14 KB     |            |   0%
# retrying-1.3.3       | 14 KB     | ########## | 100%
# retrying-1.3.3       | 14 KB     | ########## | 100%
#
# scikit-image-0.19.2  | 9.5 MB    |            |   0%
# scikit-image-0.19.2  | 9.5 MB    | 8          |   8%
# scikit-image-0.19.2  | 9.5 MB    | ##2        |  23%
# scikit-image-0.19.2  | 9.5 MB    | ###5       |  36%
# scikit-image-0.19.2  | 9.5 MB    | ####8      |  49%
# scikit-image-0.19.2  | 9.5 MB    | ######1    |  62%
# scikit-image-0.19.2  | 9.5 MB    | #######4   |  75%
# scikit-image-0.19.2  | 9.5 MB    | ########8  |  88%
# scikit-image-0.19.2  | 9.5 MB    | ########## | 100%
#
# bleach-4.1.0         | 123 KB    |            |   0%
# bleach-4.1.0         | 123 KB    | ########## | 100%
# bleach-4.1.0         | 123 KB    | ########## | 100%
#
# h5py-3.7.0           | 823 KB    |            |   0%
# h5py-3.7.0           | 823 KB    | ########## | 100%
# h5py-3.7.0           | 823 KB    | ########## | 100%
#
# sympy-1.10.1         | 9.5 MB    |            |   0%
# sympy-1.10.1         | 9.5 MB    | 9          |  10%
# sympy-1.10.1         | 9.5 MB    | ##2        |  23%
# sympy-1.10.1         | 9.5 MB    | ###5       |  36%
# sympy-1.10.1         | 9.5 MB    | ####8      |  49%
# sympy-1.10.1         | 9.5 MB    | ######2    |  62%
# sympy-1.10.1         | 9.5 MB    | #######5   |  75%
# sympy-1.10.1         | 9.5 MB    | ########8  |  88%
# sympy-1.10.1         | 9.5 MB    | ########## | 100%
#
# sqlite-3.39.2        | 805 KB    |            |   0%
# sqlite-3.39.2        | 805 KB    | ########## | 100%
# sqlite-3.39.2        | 805 KB    | ########## | 100%
#
# pywin32-302          | 5.6 MB    |            |   0%
# pywin32-302          | 5.6 MB    | #7         |  18%
# pywin32-302          | 5.6 MB    | ###9       |  40%
# pywin32-302          | 5.6 MB    | ######1    |  62%
# pywin32-302          | 5.6 MB    | ########4  |  84%
# pywin32-302          | 5.6 MB    | ########## | 100%
#
# brotli-1.0.9         | 18 KB     |            |   0%
# brotli-1.0.9         | 18 KB     | ########## | 100%
#
# curl-7.84.0          | 142 KB    |            |   0%
# curl-7.84.0          | 142 KB    | ########## | 100%
#
# cryptography-37.0.1  | 977 KB    |            |   0%
# cryptography-37.0.1  | 977 KB    | #########  |  90%
# cryptography-37.0.1  | 977 KB    | ########## | 100%
#
# dask-2022.7.0        | 20 KB     |            |   0%
# dask-2022.7.0        | 20 KB     | ########## | 100%
#
# regex-2022.7.9       | 307 KB    |            |   0%
# regex-2022.7.9       | 307 KB    | ########## | 100%
# regex-2022.7.9       | 307 KB    | ########## | 100%
#
# ...
#
# distributed-2022.7.0 | 1.1 MB    |            |   0%
# distributed-2022.7.0 | 1.1 MB    | ########   |  80%
# distributed-2022.7.0 | 1.1 MB    | ########## | 100%
#
# nest-asyncio-1.5.5   | 16 KB     |            |   0%
# nest-asyncio-1.5.5   | 16 KB     | ########## | 100%
#
# py-lief-0.11.5       | 1.7 MB    |            |   0%
# py-lief-0.11.5       | 1.7 MB    | ####       |  40%
# py-lief-0.11.5       | 1.7 MB    | ########## | 100%
# py-lief-0.11.5       | 1.7 MB    | ########## | 100%
#
# libsodium-1.0.18     | 477 KB    |            |   0%
# libsodium-1.0.18     | 477 KB    | ########## | 100%
# libsodium-1.0.18     | 477 KB    | ########## | 100%
#
# anaconda-client-1.10 | 166 KB    |            |   0%
# anaconda-client-1.10 | 166 KB    | ########## | 100%
# anaconda-client-1.10 | 166 KB    | ########## | 100%
#
# backports-1.1        | 4 KB      |            |   0%
# backports-1.1        | 4 KB      | ########## | 100%
#
# s3transfer-0.6.0     | 110 KB    |            |   0%
# s3transfer-0.6.0     | 110 KB    | ########## | 100%
#
# tzdata-2022a         | 109 KB    |            |   0%
# tzdata-2022a         | 109 KB    | ########## | 100%
# tzdata-2022a         | 109 KB    | ########## | 100%
#
# libxslt-1.1.35       | 407 KB    |            |   0%
# libxslt-1.1.35       | 407 KB    | ########## | 100%
# libxslt-1.1.35       | 407 KB    | ########## | 100%
#
# bkcharts-0.2         | 132 KB    |            |   0%
# bkcharts-0.2         | 132 KB    | ########## | 100%
# bkcharts-0.2         | 132 KB    | ########## | 100%
#
# psutil-5.9.0         | 349 KB    |            |   0%
# psutil-5.9.0         | 349 KB    | ########## | 100%
# psutil-5.9.0         | 349 KB    | ########## | 100%
#
# google-api-core-2.2. | 69 KB     |            |   0%
# google-api-core-2.2. | 69 KB     | ########## | 100%
# google-api-core-2.2. | 69 KB     | ########## | 100%
#
# docutils-0.18.1      | 666 KB    |            |   0%
# docutils-0.18.1      | 666 KB    | ########## | 100%
# docutils-0.18.1      | 666 KB    | ########## | 100%
#
# _anaconda_depends-20 | 7 KB      |            |   0%
# _anaconda_depends-20 | 7 KB      | ########## | 100%
#
# conda-package-handli | 729 KB    |            |   0%
# conda-package-handli | 729 KB    | ########## | 100%
# conda-package-handli | 729 KB    | ########## | 100%
#
# google-resumable-med | 41 KB     |            |   0%
# google-resumable-med | 41 KB     | ########## | 100%
#
# tbb-2021.5.0         | 149 KB    |            |   0%
# tbb-2021.5.0         | 149 KB    | ########## | 100%
#
# qtawesome-1.0.3      | 761 KB    |            |   0%
# qtawesome-1.0.3      | 761 KB    | ########## | 100%
# qtawesome-1.0.3      | 761 KB    | ########## | 100%
#
# mypy_extensions-0.4. | 10 KB     |            |   0%
# mypy_extensions-0.4. | 10 KB     | ########## | 100%
#
# pyasn1-0.4.8         | 54 KB     |            |   0%
# pyasn1-0.4.8         | 54 KB     | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# pyasn1-modules-0.2.8 | 72 KB     |            |   0%
# pyasn1-modules-0.2.8 | 72 KB     | ########## | 100%
# pyasn1-modules-0.2.8 | 72 KB     | ########## | 100%
#
# jedi-0.18.1          | 982 KB    |            |   0%
# jedi-0.18.1          | 982 KB    | ########## | 100%
# jedi-0.18.1          | 982 KB    | ########## | 100%
#
# colorcet-3.0.0       | 1.8 MB    |            |   0%
# colorcet-3.0.0       | 1.8 MB    | ####4      |  45%
# colorcet-3.0.0       | 1.8 MB    | ########## | 100%
# colorcet-3.0.0       | 1.8 MB    | ########## | 100%
#
# python-fastjsonschem | 29 KB     |            |   0%
# python-fastjsonschem | 29 KB     | ########## | 100%
#
# werkzeug-2.0.3       | 221 KB    |            |   0%
# werkzeug-2.0.3       | 221 KB    | ########## | 100%
# werkzeug-2.0.3       | 221 KB    | ########## | 100%
#
# notebook-6.4.12      | 4.6 MB    |            |   0%
# notebook-6.4.12      | 4.6 MB    | #7         |  17%
# notebook-6.4.12      | 4.6 MB    | ####6      |  46%
# notebook-6.4.12      | 4.6 MB    | #######3   |  73%
# notebook-6.4.12      | 4.6 MB    | #########9 | 100%
# notebook-6.4.12      | 4.6 MB    | ########## | 100%
#
# jsonschema-4.4.0     | 139 KB    |            |   0%
# jsonschema-4.4.0     | 139 KB    | ########## | 100%
# jsonschema-4.4.0     | 139 KB    | ########## | 100%
#
# ipython-8.4.0        | 1009 KB   |            |   0%
# ipython-8.4.0        | 1009 KB   | #######7   |  78%
# ipython-8.4.0        | 1009 KB   | ########## | 100%
#
# libbrotlienc-1.0.9   | 233 KB    |            |   0%
# libbrotlienc-1.0.9   | 233 KB    | ########## | 100%
#
# numpy-base-1.21.5    | 4.4 MB    |            |   0%
# numpy-base-1.21.5    | 4.4 MB    | #4         |  14%
# numpy-base-1.21.5    | 4.4 MB    | ###9       |  40%
# numpy-base-1.21.5    | 4.4 MB    | ######7    |  67%
# numpy-base-1.21.5    | 4.4 MB    | #########5 |  95%
# numpy-base-1.21.5    | 4.4 MB    | ########## | 100%
#
# jmespath-0.10.0      | 22 KB     |            |   0%
# jmespath-0.10.0      | 22 KB     | ########## | 100%
#
# bitarray-2.5.1       | 157 KB    |            |   0%
# bitarray-2.5.1       | 157 KB    | ########## | 100%
#
# platformdirs-2.4.0   | 16 KB     |            |   0%
# platformdirs-2.4.0   | 16 KB     | ########## | 100%
#
# jupyterlab_server-2. | 48 KB     |            |   0%
# jupyterlab_server-2. | 48 KB     | ########## | 100%
#
# statsmodels-0.13.2   | 8.3 MB    |            |   0%
# statsmodels-0.13.2   | 8.3 MB    | #          |  11%
# statsmodels-0.13.2   | 8.3 MB    | ##5        |  26%
# statsmodels-0.13.2   | 8.3 MB    | ####       |  41%
# statsmodels-0.13.2   | 8.3 MB    | #####5     |  55%
# statsmodels-0.13.2   | 8.3 MB    | #######    |  70%
# statsmodels-0.13.2   | 8.3 MB    | ########5  |  85%
# statsmodels-0.13.2   | 8.3 MB    | ########## | 100%
# statsmodels-0.13.2   | 8.3 MB    | ########## | 100%
#
# tomli-2.0.1          | 25 KB     |            |   0%
# tomli-2.0.1          | 25 KB     | ########## | 100%
#
# click-8.0.4          | 155 KB    |            |   0%
# click-8.0.4          | 155 KB    | ########## | 100%
#
# scikit-learn-intelex | 69 KB     |            |   0%
# scikit-learn-intelex | 69 KB     | ########## | 100%
# scikit-learn-intelex | 69 KB     | ########## | 100%
#
# libtiff-4.4.0        | 773 KB    |            |   0%
# libtiff-4.4.0        | 773 KB    | ########## | 100%
# libtiff-4.4.0        | 773 KB    | ########## | 100%
#
# certifi-2022.6.15    | 153 KB    |            |   0%
# certifi-2022.6.15    | 153 KB    | ########## | 100%
#
# numba-0.55.1         | 3.4 MB    |            |   0%
# numba-0.55.1         | 3.4 MB    | ##3        |  24%
# numba-0.55.1         | 3.4 MB    | ######2    |  62%
# numba-0.55.1         | 3.4 MB    | #########8 |  98%
# numba-0.55.1         | 3.4 MB    | ########## | 100%
#
# snowballstemmer-2.2. | 61 KB     |            |   0%
# snowballstemmer-2.2. | 61 KB     | ########## | 100%
#
# keyring-23.4.0       | 72 KB     |            |   0%
# keyring-23.4.0       | 72 KB     | ########## | 100%
# keyring-23.4.0       | 72 KB     | ########## | 100%
#
# pkginfo-1.8.2        | 27 KB     |            |   0%
# pkginfo-1.8.2        | 27 KB     | ########## | 100%
#
# grpcio-1.42.0        | 1.9 MB    |            |   0%
# grpcio-1.42.0        | 1.9 MB    | #####1     |  52%
# grpcio-1.42.0        | 1.9 MB    | ########## | 100%
#
# protego-0.1.16       | 2.2 MB    |            |   0%
# protego-0.1.16       | 2.2 MB    | ###9       |  40%
# protego-0.1.16       | 2.2 MB    | #########5 |  96%
# protego-0.1.16       | 2.2 MB    | ########## | 100%
#
# toolz-0.11.2         | 49 KB     |            |   0%
# toolz-0.11.2         | 49 KB     | ########## | 100%
# toolz-0.11.2         | 49 KB     | ########## | 100%
#
# boto3-1.24.28        | 114 KB    |            |   0%
# boto3-1.24.28        | 114 KB    | ########## | 100%
# boto3-1.24.28        | 114 KB    | ########## | 100%
#
# libbrotlidec-1.0.9   | 30 KB     |            |   0%
# libbrotlidec-1.0.9   | 30 KB     | ########## | 100%
#
# attrs-21.4.0         | 51 KB     |            |   0%
# attrs-21.4.0         | 51 KB     | ########## | 100%
#
# nbconvert-6.4.4      | 517 KB    |            |   0%
# nbconvert-6.4.4      | 517 KB    | ########## | 100%
# nbconvert-6.4.4      | 517 KB    | ########## | 100%
#
# googleapis-common-pr | 131 KB    |            |   0%
# googleapis-common-pr | 131 KB    | ########## | 100%
# googleapis-common-pr | 131 KB    | ########## | 100%
#
# aiohttp-3.8.1        | 496 KB    |            |   0%
# aiohttp-3.8.1        | 496 KB    | ########## | 100%
# aiohttp-3.8.1        | 496 KB    | ########## | 100%
#
# arrow-1.2.2          | 92 KB     |            |   0%
# arrow-1.2.2          | 92 KB     | ########## | 100%
#
# rsa-4.7.2            | 28 KB     |            |   0%
# rsa-4.7.2            | 28 KB     | ########## | 100%
#
# tqdm-4.64.0          | 155 KB    |            |   0%
# tqdm-4.64.0          | 155 KB    | ########## | 100%
# tqdm-4.64.0          | 155 KB    | ########## | 100%
#
# bokeh-2.4.3          | 7.6 MB    |            |   0%
# bokeh-2.4.3          | 7.6 MB    | #2         |  13%
# bokeh-2.4.3          | 7.6 MB    | ##7        |  28%
# bokeh-2.4.3          | 7.6 MB    | ####3      |  44%
# bokeh-2.4.3          | 7.6 MB    | #####9     |  60%
# bokeh-2.4.3          | 7.6 MB    | #######6   |  76%
# bokeh-2.4.3          | 7.6 MB    | #########2 |  92%
# bokeh-2.4.3          | 7.6 MB    | ########## | 100%
#
# queuelib-1.5.0       | 259 KB    |            |   0%
# queuelib-1.5.0       | 259 KB    | ########## | 100%
# queuelib-1.5.0       | 259 KB    | ########## | 100%
#
# libiconv-1.16        | 651 KB    |            |   0%
# libiconv-1.16        | 651 KB    | ########## | 100%
# libiconv-1.16        | 651 KB    | ########## | 100%
#
# typing_extensions-4. | 42 KB     |            |   0%
# typing_extensions-4. | 42 KB     | ########## | 100%
#
# numexpr-2.8.3        | 119 KB    |            |   0%
# numexpr-2.8.3        | 119 KB    | ########## | 100%
#
# autopep8-1.6.0       | 42 KB     |            |   0%
# autopep8-1.6.0       | 42 KB     | ########## | 100%
#
# executing-0.8.3      | 18 KB     |            |   0%
# executing-0.8.3      | 18 KB     | ########## | 100%
#
# xlsxwriter-3.0.3     | 113 KB    |            |   0%
# xlsxwriter-3.0.3     | 113 KB    | ########## | 100%
#
# datashader-0.14.1    | 16.5 MB   |            |   0%
# datashader-0.14.1    | 16.5 MB   | 4          |   5%
# datashader-0.14.1    | 16.5 MB   | #2         |  12%
# datashader-0.14.1    | 16.5 MB   | #9         |  20%
# datashader-0.14.1    | 16.5 MB   | ##6        |  27%
# datashader-0.14.1    | 16.5 MB   | ###3       |  33%
# datashader-0.14.1    | 16.5 MB   | ####       |  41%
# datashader-0.14.1    | 16.5 MB   | ####8      |  48%
# datashader-0.14.1    | 16.5 MB   | #####5     |  56%
# datashader-0.14.1    | 16.5 MB   | ######3    |  63%
# datashader-0.14.1    | 16.5 MB   | #######    |  71%
# datashader-0.14.1    | 16.5 MB   | #######8   |  78%
# datashader-0.14.1    | 16.5 MB   | ########5  |  85%
# datashader-0.14.1    | 16.5 MB   | #########2 |  93%
# datashader-0.14.1    | 16.5 MB   | ########## | 100%
#
# msgpack-python-1.0.3 | 75 KB     |            |   0%
# msgpack-python-1.0.3 | 75 KB     | ########## | 100%
#
# sqlalchemy-1.4.39    | 1.9 MB    |            |   0%
# sqlalchemy-1.4.39    | 1.9 MB    | ####2      |  43%
# sqlalchemy-1.4.39    | 1.9 MB    | ########## | 100%
# sqlalchemy-1.4.39    | 1.9 MB    | ########## | 100%
#
# numpydoc-1.4.0       | 86 KB     |            |   0%
# numpydoc-1.4.0       | 86 KB     | ########## | 100%
# numpydoc-1.4.0       | 86 KB     | ########## | 100%
#
# patsy-0.5.2          | 276 KB    |            |   0%
# patsy-0.5.2          | 276 KB    | ########## | 100%
# patsy-0.5.2          | 276 KB    | ########## | 100%
#
# ujson-5.4.0          | 44 KB     |            |   0%
# ujson-5.4.0          | 44 KB     | ########## | 100%
#
# kiwisolver-1.4.2     | 58 KB     |            |   0%
# kiwisolver-1.4.2     | 58 KB     | ########## | 100%
#
# async-timeout-4.0.1  | 10 KB     |            |   0%
# async-timeout-4.0.1  | 10 KB     | ########## | 100%
#
# websocket-client-0.5 | 69 KB     |            |   0%
# websocket-client-0.5 | 69 KB     | ########## | 100%
#
# automat-20.2.0       | 31 KB     |            |   0%
# automat-20.2.0       | 31 KB     | ########## | 100%
#
# pynacl-1.5.0         | 1.2 MB    |            |   0%
# pynacl-1.5.0         | 1.2 MB    | #######1   |  71%
# pynacl-1.5.0         | 1.2 MB    | ########## | 100%
#
# filelock-3.6.0       | 12 KB     |            |   0%
# filelock-3.6.0       | 12 KB     | ########## | 100%
#
# qtconsole-5.3.1      | 192 KB    |            |   0%
# qtconsole-5.3.1      | 192 KB    | ########## | 100%
# qtconsole-5.3.1      | 192 KB    | ########## | 100%
#
# cssselect-1.1.0      | 18 KB     |            |   0%
# cssselect-1.1.0      | 18 KB     | ########## | 100%
#
# cfitsio-3.470        | 518 KB    |            |   0%
# cfitsio-3.470        | 518 KB    | ########## | 100%
# cfitsio-3.470        | 518 KB    | ########## | 100%
#
# constantly-15.1.0    | 10 KB     |            |   0%
# constantly-15.1.0    | 10 KB     | ########## | 100%
#
# pycparser-2.21       | 94 KB     |            |   0%
# pycparser-2.21       | 94 KB     | ########## | 100%
# pycparser-2.21       | 94 KB     | ########## | 100%
#
# prometheus_client-0. | 89 KB     |            |   0%
# prometheus_client-0. | 89 KB     | ########## | 100%
#
# multidict-5.1.0      | 61 KB     |            |   0%
# multidict-5.1.0      | 61 KB     | ########## | 100%
# multidict-5.1.0      | 61 KB     | ########## | 100%
#
# pytz-2022.1          | 195 KB    |            |   0%
# pytz-2022.1          | 195 KB    | ########## | 100%
# pytz-2022.1          | 195 KB    | ########## | 100%
#
# twisted-22.2.0       | 4.2 MB    |            |   0%
# twisted-22.2.0       | 4.2 MB    | ##3        |  23%
# twisted-22.2.0       | 4.2 MB    | #####1     |  51%
# twisted-22.2.0       | 4.2 MB    | ########   |  81%
# twisted-22.2.0       | 4.2 MB    | ########## | 100%
#
# libbrotlicommon-1.0. | 71 KB     |            |   0%
# libbrotlicommon-1.0. | 71 KB     | ########## | 100%
#
# snappy-1.1.9         | 2.2 MB    |            |   0%
# snappy-1.1.9         | 2.2 MB    | ###2       |  33%
# snappy-1.1.9         | 2.2 MB    | ########9  |  89%
# snappy-1.1.9         | 2.2 MB    | ########## | 100%
#
# tabulate-0.8.10      | 62 KB     |            |   0%
# tabulate-0.8.10      | 62 KB     | ########## | 100%
#
# zipp-3.8.0           | 20 KB     |            |   0%
# zipp-3.8.0           | 20 KB     | ########## | 100%
#
# nltk-3.7             | 1010 KB   |            |   0%
# nltk-3.7             | 1010 KB   | #######6   |  76%
# nltk-3.7             | 1010 KB   | ########## | 100%
#
# pillow-9.2.0         | 908 KB    |            |   0%
# pillow-9.2.0         | 908 KB    | ########## | 100%
# pillow-9.2.0         | 908 KB    | ########## | 100%
#
# gensim-4.1.2         | 18.3 MB   |            |   0%
# gensim-4.1.2         | 18.3 MB   | 4          |   5%
# gensim-4.1.2         | 18.3 MB   | #1         |  12%
# gensim-4.1.2         | 18.3 MB   | #8         |  18%
# gensim-4.1.2         | 18.3 MB   | ##5        |  25%
# gensim-4.1.2         | 18.3 MB   | ###1       |  32%
# gensim-4.1.2         | 18.3 MB   | ###8       |  39%
# gensim-4.1.2         | 18.3 MB   | ####5      |  46%
# gensim-4.1.2         | 18.3 MB   | #####2     |  52%
# gensim-4.1.2         | 18.3 MB   | #####9     |  59%
# gensim-4.1.2         | 18.3 MB   | ######5    |  66%
# gensim-4.1.2         | 18.3 MB   | #######2   |  73%
# gensim-4.1.2         | 18.3 MB   | #######9   |  80%
# gensim-4.1.2         | 18.3 MB   | ########6  |  86%
# gensim-4.1.2         | 18.3 MB   | #########3 |  93%
# gensim-4.1.2         | 18.3 MB   | ########## | 100%
#
# importlib_metadata-4 | 12 KB     |            |   0%
# importlib_metadata-4 | 12 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Train | Test Split and Scaling
#
# * for train_test_split use fallowing arguments:
#     * train_size: 0.2
#     * stratify: True
#     * random_state: 10
# * Use StandardScaler to scale the data.

# %% [markdown]
# # Logistic Regression
#
# * Train the model using the training set with the default parameters.

# %% [markdown]
# ## Model Performance
# *Check the accuracy of the model using the train and test set by given eval_metric function.

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):

    """ to get the metrics for the model """

    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %% [markdown]
# ### Cross Validate
#
# * Use the cross_val_score function to evaluate the model using the train set.

# %% [markdown]
# ### GridSearchCV
# * Use the GridSearchCV function to find the best parameters for the model.

# %% [markdown]
# ## ROC (Receiver Operating Curve) and AUC (Area Under Curve)
#
# * Use the roc_curve function to calculate the ROC curve and compare logistic regression models with default and tuned parameters.

# %% [markdown]
# ## KNN (K-Nearest Neighbors)
# * Train the model using the training set with the default parameters.

# %% [markdown]
# ### Elbow Method for Choosing Reasonable K Values
# * Use the elbow method to find the optimal number of neighbors.

# %% [markdown]
# ### Scores by Various K Values
# * Select some k values smaller and bigger than the optimal k value to see how the model performs.

# %% [markdown]
# ### Cross Validate
# * Use the cross_val_score function to evaluate the model using the train set. Use optimal k value which you found in the elbow method.

# %% [markdown]
# ### Gridsearch Method for Choosing Reasonable K Values
# * Use the GridSearchCV function to find the best parameters for the model. this method is brute force method to find the best parameters, and it takes a long time to run for KNN. You will get different k values because of you will use different parameters, and also gridsearch method tries to find minimum error. Sometimes it get larger k values for optimal but for  sake of reduce complexity we use the elbow method to find the optimal k value.

# %% [markdown]
# ### Evaluating ROC Curves and AUC
# *Use the roc_curve function to calculate the ROC curve and compare KNN models with default and tuned parameters.

# %% [markdown]
# # Conclusion
# * Write a short summary of your findings, and decide which model you will use and why.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
